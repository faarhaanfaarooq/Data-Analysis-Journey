# %% [markdown]
# <a href="https://colab.research.google.com/github/farhann-farooq/Data-Analysis-Journey/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importing Matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### linear Plot

# %%
x = [60, 30, 45, 100]
y = [10, 5, 11, 7]
plt.plot(x, y, marker = "o")
# separate graph at x- axis
plt.plot(x, marker = "^")
# separate graph at y- axis
plt.plot(y, marker = "^")
plt.show()

# %% [markdown]
# ### Bar Graph

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
plt.bar(x, y)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
c = ['r', 'g', 'b', 'y', 'b' ]
plt.bar(x, y, color = c)
plt.show()

# %% [markdown]
# ### showing bar graph horizontally

# %%
import numpy as np

# %%
x = np.array(['a', 'b', 'c', 'd'])
y = np.array([10, 20, 30, 40])
plt.barh(x, y)
plt.show()

# %%
x = np.array(['a', 'b', 'c', 'd'])
y = np.array([10, 20, 30, 40])
plt.bar(x, y, width=0.1)
plt.show()

# %% [markdown]
# ### ScatterPlot

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
plt.title("Scatter Plot")
plt.xlabel("Person")
plt.ylabel("Numbers")
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ### Turning any image to black and white

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

fname = r'motabhai.jpg'

image = Image.open(fname).convert('L')

plt.imshow(image, cmap='gray')
plt.show()

# %% [markdown]
# ### Pie chart

# %%
x = [40, 20, 10, 30]
y = ['Math', 'English', 'Bangla', 'Physics']
plt.pie(x, labels = y)
plt.show()
